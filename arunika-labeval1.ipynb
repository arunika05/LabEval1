# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/how-to-be-instagram-famous-with-data-science/dev.csv
# /kaggle/input/how-to-be-instagram-famous-with-data-science/comp.csv
# /kaggle/input/how-to-be-instagram-famous-with-data-science/sample_submission.csv

# %%
import cudf
import cupy
import cuml
from cuml.preprocessing import StandardScaler
from cuml.preprocessing.LabelEncoder import LabelEncoder
from cuml import LogisticRegression
from cuml.metrics import accuracy_score
from cuml.ensemble import RandomForestClassifier as cuRFC
from cuml.model_selection import train_test_split

# %%
comp_df=cudf.read_csv("../input/how-to-be-instagram-famous-with-data-science/comp.csv")
comp_df
# Out:
#       page_likes  page_interaction  page_category  tot_no_comments_bef  \
# 0           9412               882             44                    0
# 1       12502091             36590             14                  117
# 2           4590              1050             18                    5
# 3         136038                36             55                    0
# 4         100214              1287             32                    3
# ...          ...               ...            ...                  ...
# 1995       14685                72             17                    0
# 1996       68308              3902              2                   37
# 1997     1422095             35699              9                   47
# 1998       37066                37             90                   16
# 1999      101184              4190             24                   26
#
#       no_comments_24h  no_comments_48_24h  no_comments_24h_after_pub  \
# 0                   0                   0                          0
# 1                 107                   0                        111
# 2                   1                   0                          4
# 3                   0                   0                          0
# 4                   0                   3                          3
# ...               ...                 ...                        ...
# 1995                0                   0                          0
# 1996                2                   3                         29
# 1997               41                   0                         43
# 1998               14                   0                         15
# 1999               21                   0                         23
#
#       delta_48_24h  character_count_post  no_shares_post day_posted  \
# 0                0                   177               1    TUESDAY
# 1              104                     0             171     FRIDAY
# 2                1                    18               2  WEDNESDAY
# 3                0                   366               1  WEDNESDAY
# 4               -3                   213               1   THURSDAY
# ...            ...                   ...             ...        ...
# 1995             0                    64               1   SATURDAY
# 1996            -1                   133               4   THURSDAY
# 1997            38                    99             231    TUESDAY
# 1998             8                    73               2    TUESDAY
# 1999            17                   126              40     MONDAY
#
#      current_day has_new_comments      ID
# 0      WEDNESDAY             <NA>     CP1
# 1       SATURDAY             <NA>     CP2
# 2       SATURDAY             <NA>     CP3
# 3       THURSDAY             <NA>     CP4
# 4       SATURDAY             <NA>     CP5
# ...          ...              ...     ...
# 1995     TUESDAY             <NA>  CP1996
# 1996      SUNDAY             <NA>  CP1997
# 1997     TUESDAY             <NA>  CP1998
# 1998   WEDNESDAY             <NA>  CP1999
# 1999     TUESDAY             <NA>  CP2000
#
# [2000 rows x 14 columns]

# %%
dev_df=cudf.read_csv("../input/how-to-be-instagram-famous-with-data-science/dev.csv")
dev_df
# Out:
#       page_likes  page_interaction  page_category  tot_no_comments_bef  \
# 0         633016            168920             18                  143
# 1         115669               745              1                    3
# 2         640987             84288              1                    5
# 3        4913787            158828              9                   77
# 4         274207            100435             18                  250
# ...          ...               ...            ...                  ...
# 9084       83215             12259             18                   10
# 9085      420838               606             39                    9
# 9086       10039              1151             56                    1
# 9087      879585             49540              9                    1
# 9088       50469              2456             32                   22
#
#       no_comments_24h  no_comments_48_24h  no_comments_24h_after_pub  \
# 0                 143                   0                        143
# 1                   1                   1                          2
# 2                   1                   4                          5
# 3                   2                  75                         75
# 4                  22                 228                        237
# ...               ...                 ...                        ...
# 9084               10                   0                         10
# 9085                0                   4                          6
# 9086                0                   1                          1
# 9087                1                   0                          1
# 9088                3                  19                         21
#
#       delta_48_24h  character_count_post  no_shares_post day_posted  \
# 0              143                    50             307  WEDNESDAY
# 1                0                    19              13     MONDAY
# 2               -3                    61              86     FRIDAY
# 3              -73                   150              33   THURSDAY
# 4             -206                     8              36  WEDNESDAY
# ...            ...                   ...             ...        ...
# 9084            10                   118              13    TUESDAY
# 9085            -4                    44              42     FRIDAY
# 9086            -1                   377               1   SATURDAY
# 9087             1                     0               6   SATURDAY
# 9088           -16                   616              48   THURSDAY
#
#      current_day has_new_comments     ID
# 0      WEDNESDAY              yes  P5548
# 1       THURSDAY               no  P3655
# 2         SUNDAY               no  P1424
# 3       SATURDAY               no  P6393
# 4         FRIDAY              yes  P5068
# ...          ...              ...    ...
# 9084   WEDNESDAY              yes  P7533
# 9085      MONDAY               no  P3873
# 9086      SUNDAY               no  P9036
# 9087    SATURDAY              yes  P9055
# 9088    SATURDAY              yes  P8207
#
# [9089 rows x 14 columns]

# %%
y = dev_df['has_new_comments']
y
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4       yes
#        ...
# 9084    yes
# 9085     no
# 9086     no
# 9087    yes
# 9088    yes
# Name: has_new_comments, Length: 9089, dtype: object

# %%
dev_df.info()
# Out:
# <class 'cudf.core.dataframe.DataFrame'>
# RangeIndex: 9089 entries, 0 to 9088
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   page_likes                 9089 non-null   int64
#  1   page_interaction           9089 non-null   int64
#  2   page_category              9089 non-null   int64
#  3   tot_no_comments_bef        9089 non-null   int64
#  4   no_comments_24h            9089 non-null   int64
#  5   no_comments_48_24h         9089 non-null   int64
#  6   no_comments_24h_after_pub  9089 non-null   int64
#  7   delta_48_24h               9089 non-null   int64
#  8   character_count_post       9089 non-null   int64
#  9   no_shares_post             9089 non-null   int64
#  10  day_posted                 9089 non-null   object
#  11  current_day                9089 non-null   object
#  12  has_new_comments           9089 non-null   object
#  13  ID                         9089 non-null   object
# dtypes: int64(10), object(4)
# memory usage: 1.0+ MB

# %%
comp_df.info()
# Out:
# <class 'cudf.core.dataframe.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   page_likes                 2000 non-null   int64
#  1   page_interaction           2000 non-null   int64
#  2   page_category              2000 non-null   int64
#  3   tot_no_comments_bef        2000 non-null   int64
#  4   no_comments_24h            2000 non-null   int64
#  5   no_comments_48_24h         2000 non-null   int64
#  6   no_comments_24h_after_pub  2000 non-null   int64
#  7   delta_48_24h               2000 non-null   int64
#  8   character_count_post       2000 non-null   int64
#  9   no_shares_post             2000 non-null   int64
#  10  day_posted                 2000 non-null   object
#  11  current_day                2000 non-null   object
#  12  has_new_comments           0 non-null      int8
#  13  ID                         2000 non-null   object
# dtypes: int64(10), int8(1), object(3)
# memory usage: 220.5+ KB

# %%
df_train=dev_df.drop(['ID','has_new_comments'], axis = 1)
df_train
# Out:
#       page_likes  page_interaction  page_category  tot_no_comments_bef  \
# 0         633016            168920             18                  143
# 1         115669               745              1                    3
# 2         640987             84288              1                    5
# 3        4913787            158828              9                   77
# 4         274207            100435             18                  250
# ...          ...               ...            ...                  ...
# 9084       83215             12259             18                   10
# 9085      420838               606             39                    9
# 9086       10039              1151             56                    1
# 9087      879585             49540              9                    1
# 9088       50469              2456             32                   22
#
#       no_comments_24h  no_comments_48_24h  no_comments_24h_after_pub  \
# 0                 143                   0                        143
# 1                   1                   1                          2
# 2                   1                   4                          5
# 3                   2                  75                         75
# 4                  22                 228                        237
# ...               ...                 ...                        ...
# 9084               10                   0                         10
# 9085                0                   4                          6
# 9086                0                   1                          1
# 9087                1                   0                          1
# 9088                3                  19                         21
#
#       delta_48_24h  character_count_post  no_shares_post day_posted  \
# 0              143                    50             307  WEDNESDAY
# 1                0                    19              13     MONDAY
# 2               -3                    61              86     FRIDAY
# 3              -73                   150              33   THURSDAY
# 4             -206                     8              36  WEDNESDAY
# ...            ...                   ...             ...        ...
# 9084            10                   118              13    TUESDAY
# 9085            -4                    44              42     FRIDAY
# 9086            -1                   377               1   SATURDAY
# 9087             1                     0               6   SATURDAY
# 9088           -16                   616              48   THURSDAY
#
#      current_day
# 0      WEDNESDAY
# 1       THURSDAY
# 2         SUNDAY
# 3       SATURDAY
# 4         FRIDAY
# ...          ...
# 9084   WEDNESDAY
# 9085      MONDAY
# 9086      SUNDAY
# 9087    SATURDAY
# 9088    SATURDAY
#
# [9089 rows x 12 columns]

# %%
print(df_train.day_posted.unique())
# Out:
# 0       FRIDAY
# 1       MONDAY
# 2     SATURDAY
# 3       SUNDAY
# 4     THURSDAY
# 5      TUESDAY
# 6    WEDNESDAY
# Name: day_posted, dtype: object

# %%
data=cudf.get_dummies(df_train,columns=['current_day','day_posted'])
data
# Out:
#       page_likes  page_interaction  page_category  tot_no_comments_bef  \
# 0         633016            168920             18                  143
# 1         115669               745              1                    3
# 2         640987             84288              1                    5
# 3        4913787            158828              9                   77
# 4         274207            100435             18                  250
# ...          ...               ...            ...                  ...
# 9084       83215             12259             18                   10
# 9085      420838               606             39                    9
# 9086       10039              1151             56                    1
# 9087      879585             49540              9                    1
# 9088       50469              2456             32                   22
#
#       no_comments_24h  no_comments_48_24h  no_comments_24h_after_pub  \
# 0                 143                   0                        143
# 1                   1                   1                          2
# 2                   1                   4                          5
# 3                   2                  75                         75
# 4                  22                 228                        237
# ...               ...                 ...                        ...
# 9084               10                   0                         10
# 9085                0                   4                          6
# 9086                0                   1                          1
# 9087                1                   0                          1
# 9088                3                  19                         21
#
#       delta_48_24h  character_count_post  no_shares_post  ...  \
# 0              143                    50             307  ...
# 1                0                    19              13  ...
# 2               -3                    61              86  ...
# 3              -73                   150              33  ...
# 4             -206                     8              36  ...
# ...            ...                   ...             ...  ...
# 9084            10                   118              13  ...
# 9085            -4                    44              42  ...
# 9086            -1                   377               1  ...
# 9087             1                     0               6  ...
# 9088           -16                   616              48  ...
#
#       current_day_THURSDAY  current_day_TUESDAY  current_day_WEDNESDAY  \
# 0                        0                    0                      1
# 1                        1                    0                      0
# 2                        0                    0                      0
# 3                        0                    0                      0
# 4                        0                    0                      0
# ...                    ...                  ...                    ...
# 9084                     0                    0                      1
# 9085                     0                    0                      0
# 9086                     0                    0                      0
# 9087                     0                    0                      0
# 9088                     0                    0                      0
#
#       day_posted_FRIDAY  day_posted_MONDAY  day_posted_SATURDAY  \
# 0                     0                  0                    0
# 1                     0                  1                    0
# 2                     1                  0                    0
# 3                     0                  0                    0
# 4                     0                  0                    0
# ...                 ...                ...                  ...
# 9084                  0                  0                    0
# 9085                  1                  0                    0
# 9086                  0                  0                    1
# 9087                  0                  0                    1
# 9088                  0                  0                    0
#
#       day_posted_SUNDAY  day_posted_THURSDAY  day_posted_TUESDAY  \
# 0                     0                    0                   0
# 1                     0                    0                   0
# 2                     0                    0                   0
# 3                     0                    1                   0
# 4                     0                    0                   0
# ...                 ...                  ...                 ...
# 9084                  0                    0                   1
# 9085                  0                    0                   0
# 9086                  0                    0                   0
# 9087                  0                    0                   0
# 9088                  0                    1                   0
#
#       day_posted_WEDNESDAY
# 0                        1
# 1                        0
# 2                        0
# 3                        0
# 4                        1
# ...                    ...
# 9084                     0
# 9085                     0
# 9086                     0
# 9087                     0
# 9088                     0
#
# [9089 rows x 24 columns]

# %%
scaler = StandardScaler()
df_scaled_one=scaler.fit_transform(data)
df_scaled_one
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.075443  1.151313 -0.318787  0.692574  1.590222 -0.268763  0.760943
# 1    -0.131462 -0.371528 -1.160898 -0.384740 -0.267195 -0.254420 -0.393756
# 2    -0.074580  0.384962 -1.160898 -0.369350 -0.267195 -0.211390 -0.369188
# 3     0.388091  1.059929 -0.764611  0.184698 -0.254114  0.806968  0.204067
# 4    -0.114295  0.531174 -0.318787  1.515950  0.007494  3.001458  1.530742
# ...        ...       ...       ...       ...       ...       ...       ...
# 9084 -0.134977 -0.267268 -0.318787 -0.330874 -0.149471 -0.268763 -0.328241
# 9085 -0.098418 -0.372787  0.721468 -0.338569 -0.280275 -0.211390 -0.360998
# 9086 -0.142900 -0.367852  1.563579 -0.400130 -0.280275 -0.254420 -0.401945
# 9087 -0.048744  0.070315 -0.764611 -0.400130 -0.267195 -0.268763 -0.401945
# 9088 -0.138522 -0.356035  0.374716 -0.238533 -0.241034  0.003756 -0.238158
#
#             7         8         9   ...        14        15        16  \
# 0     1.505210 -0.272502  0.337103  ... -0.400434 -0.398026  2.315252
# 1    -0.028846 -0.343601 -0.178149  ...  2.497292 -0.398026 -0.431918
# 2    -0.061029 -0.247274 -0.050212  ... -0.400434 -0.398026 -0.431918
# 3    -0.811966 -0.043152 -0.143097  ... -0.400434 -0.398026 -0.431918
# 4    -2.238745 -0.368829 -0.137840  ... -0.400434 -0.398026 -0.431918
# ...        ...       ...       ...  ...       ...       ...       ...
# 9084  0.078430 -0.116544 -0.178149  ... -0.400434 -0.398026  2.315252
# 9085 -0.071757 -0.286263 -0.127324  ... -0.400434 -0.398026 -0.431918
# 9086 -0.039574  0.477472 -0.199179  ... -0.400434 -0.398026 -0.431918
# 9087 -0.018119 -0.387177 -0.190416  ... -0.400434 -0.398026 -0.431918
# 9088 -0.200489  1.025619 -0.116809  ... -0.400434 -0.398026 -0.431918
#
#             17        18        19        20        21        22        23
# 0    -0.425445 -0.404862 -0.410917 -0.374511 -0.408353 -0.417843  2.410029
# 1    -0.425445  2.469976 -0.410917 -0.374511 -0.408353 -0.417843 -0.414933
# 2     2.350482 -0.404862 -0.410917 -0.374511 -0.408353 -0.417843 -0.414933
# 3    -0.425445 -0.404862 -0.410917 -0.374511  2.448861 -0.417843 -0.414933
# 4    -0.425445 -0.404862 -0.410917 -0.374511 -0.408353 -0.417843  2.410029
# ...        ...       ...       ...       ...       ...       ...       ...
# 9084 -0.425445 -0.404862 -0.410917 -0.374511 -0.408353  2.393242 -0.414933
# 9085  2.350482 -0.404862 -0.410917 -0.374511 -0.408353 -0.417843 -0.414933
# 9086 -0.425445 -0.404862  2.433581 -0.374511 -0.408353 -0.417843 -0.414933
# 9087 -0.425445 -0.404862  2.433581 -0.374511 -0.408353 -0.417843 -0.414933
# 9088 -0.425445 -0.404862 -0.410917 -0.374511  2.448861 -0.417843 -0.414933
#
# [9089 rows x 24 columns]

# %%
type(df_scaled_one),type(y)
# Out:
# (cudf.core.dataframe.DataFrame, cudf.core.series.Series)

# %%
le = LabelEncoder()
y = le.fit_transform(y)
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 9084    1
# 9085    0
# 9086    0
# 9087    1
# 9088    1
# Length: 9089, dtype: uint8

# %%
df_test=comp_df.drop(['ID','has_new_comments'], axis = 1)
df_test
# Out:
#       page_likes  page_interaction  page_category  tot_no_comments_bef  \
# 0           9412               882             44                    0
# 1       12502091             36590             14                  117
# 2           4590              1050             18                    5
# 3         136038                36             55                    0
# 4         100214              1287             32                    3
# ...          ...               ...            ...                  ...
# 1995       14685                72             17                    0
# 1996       68308              3902              2                   37
# 1997     1422095             35699              9                   47
# 1998       37066                37             90                   16
# 1999      101184              4190             24                   26
#
#       no_comments_24h  no_comments_48_24h  no_comments_24h_after_pub  \
# 0                   0                   0                          0
# 1                 107                   0                        111
# 2                   1                   0                          4
# 3                   0                   0                          0
# 4                   0                   3                          3
# ...               ...                 ...                        ...
# 1995                0                   0                          0
# 1996                2                   3                         29
# 1997               41                   0                         43
# 1998               14                   0                         15
# 1999               21                   0                         23
#
#       delta_48_24h  character_count_post  no_shares_post day_posted  \
# 0                0                   177               1    TUESDAY
# 1              104                     0             171     FRIDAY
# 2                1                    18               2  WEDNESDAY
# 3                0                   366               1  WEDNESDAY
# 4               -3                   213               1   THURSDAY
# ...            ...                   ...             ...        ...
# 1995             0                    64               1   SATURDAY
# 1996            -1                   133               4   THURSDAY
# 1997            38                    99             231    TUESDAY
# 1998             8                    73               2    TUESDAY
# 1999            17                   126              40     MONDAY
#
#      current_day
# 0      WEDNESDAY
# 1       SATURDAY
# 2       SATURDAY
# 3       THURSDAY
# 4       SATURDAY
# ...          ...
# 1995     TUESDAY
# 1996      SUNDAY
# 1997     TUESDAY
# 1998   WEDNESDAY
# 1999     TUESDAY
#
# [2000 rows x 12 columns]

# %%
test_data=cudf.get_dummies(df_test,columns=['current_day','day_posted'])
#from cuml.preprocessing import StandardScaler
#scaler = StandardScaler()
df_scaled_test=scaler.fit_transform(test_data)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(df_scaled_one,y,test_size=0.2,random_state=0)

# %%
reg = LogisticRegression()
reg.fit(df_scaled_one,y)
print("Coefficients:")
print(reg.coef_)
print("Intercept:")
print(reg.intercept_)
preds = reg.predict(X_valid)
print("Predictions:")
print(preds)
# Out:
# Coefficients:
# 0    -0.115177
# 1     0.081278
# 2    -0.054355
# 3     0.835509
# 4     8.779250
# 5     3.597744
# 6    -0.681570
# 7     4.509277
# 8     0.072184
# 9     0.111214
# 10    0.023809
# 11   -0.004063
# 12   -0.044684
# 13    0.009529
# 14   -0.034888
# 15    0.006766
# 16    0.040958
# 17    0.009498
# 18   -0.042762
# 19    0.028102
# 20   -0.011318
# 21    0.008194
# 22   -0.017956
# 23    0.024890
# dtype: float64
# Intercept:
# 0    2.334852
# dtype: float64
# Predictions:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1812    0
# 1813    1
# 1814    1
# 1815    1
# 1816    0
# Length: 1817, dtype: uint8

# %%
from cuml.ensemble import RandomForestClassifier as cuRFC
rfc_model = cuRFC(max_features=1.0,
                   n_bins=10,
                   n_estimators=40)
rfc_model.fit(X_train,y_train)
rfc_predict = rfc_model.predict(X_valid)
score_rf=accuracy_score(y_valid,rfc_predict)
score_rf
# Out:
# /opt/conda/lib/python3.7/site-packages/cuml/internals/api_decorators.py:567: UserWarning: To use pickling or GPU-based prediction first train using float32 data to fit the estimator
#   ret_val = func(*args, **kwargs)
# /opt/conda/lib/python3.7/site-packages/cuml/internals/api_decorators.py:586: UserWarning: GPU based predict only accepts np.float32 data. The model was trained on np.float64 data hence cannot use GPU-based prediction!
# Defaulting to CPU-based Prediction.
# To predict on float-64 data, set parameter predict_model = 'CPU'
#   ret_val = func(*args, **kwargs)
# 0.8057237267494202

# %%
score = accuracy_score(y_valid,preds)
score
# Out:
# 0.7969179749488831
